# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os

load_dotenv()

client = Anthropic(api_key=os.environ.get("ANTRHOPIC_API_KEY"))
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset_coding.json'
dataset = generate_dataset()
with open("dataset_coding.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset_coding.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 URI Parser\n\nHere's a Python function that parses AWS S3 bucket URIs:\n\n```python\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket name and key.\n    \n    Args:\n        uri (str): S3 URI in the format 's3://bucket-name/path/to/object'\n    \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' keys\n    \n    Raises:\n        ValueError: If URI format is invalid\n    \n    Example:\n        >>> parse_s3_uri('s3://my-bucket/path/to/file.txt')\n        {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \"\"\"\n    if not isinstance(uri, str):\n        raise ValueError(\"URI must be a string\")\n    \n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = uri[5:]\n    \n    # Split on first '/'\n    parts = uri_without_prefix.split('/', 1)\n    \n    if len(parts) < 1 or not parts[0]:\n        raise ValueError(\"Invalid S3 URI: bucket name is missing\")\n    \n    bucket = parts[0]\n    key = parts[1] if len(parts) > 1 else \"\"\n    \n    if not key:\n        raise ValueError(\"Invalid S3 URI: object key is missing\")\n    \n    return {\n        'bucket': bucket,\n        'key': key\n    }\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Valid URIs\n    print(parse_s3_uri('s3://my-bucket/path/to/file.txt'))\n    # Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \n    print(parse_s3_uri('s3://data-bucket/documents/report.pdf'))\n    # Output: {'bucket': 'data-bucket', 'key': 'documents/report.pdf'}\n    \n    print(parse_s3_uri('s3://logs/2024/01/15/app.log'))\n    # Output: {'bucket': 'logs', 'key': '2024/01/15/app.log'}\n    \n    # Invalid URIs\n    try:\n        parse_s3_uri('https://my-bucket/file.txt')\n    except ValueError as e:\n        print(f\"Error: {e}\")\n    \n    try:\n        parse_s3_uri('s3://my-bucket')\n    except ValueError as e:\n        print(f\"Error: {e}\")\n```\n\n## Alternative Version (More Lenient)\n\nIf you want to allow optional keys:\n\n```python\ndef parse_s3_uri_lenient(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI with optional key.\n    \n    Args:\n        uri (str): S3 URI in the format 's3://bucket-name/path/to/object' or 's3://bucket-name/'\n    \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' keys (key can be empty string)\n    \"\"\"\n    if not isinstance(uri, str):\n        raise ValueError(\"URI must be a string\")\n    \n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    uri_without_prefix = uri[5:]\n    parts = uri_without_prefix.split('/', 1)\n    \n    if not parts[0]:\n        raise ValueError(\"Invalid S3 URI: bucket name is missing\")\n    \n    return {\n        'bucket': parts[0],\n        'key': parts[1] if len(parts) > 1 else \"\"\n    }\n\n# Test\nprint(parse_s3_uri_lenient('s3://my-bucket/'))\n# Output: {'bucket': 'my-bucket', 'key': ''}\n```\n\n## Using `urllib.parse` (More",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with keys 'bucket' and 'key'"
#     },
#     "score": 6,
#     "reasoning": "The solution correctly implements core parsing logic and demonstrates good software engineering practices with documentation and error handling. However, it has a design flaw in the strict version that unnecessarily rejects valid S3 URIs, lacks bucket name validation against AWS constraints, and appears incomplete. For a production AWS tool, bucket validation would be important. The lenient version is more practical, but the task requirements are ambiguous about whether to require keys, making the strict version's design questionable."
#   },
#   {
#     "output": "# AWS IAM Policy for S3 Read-Only Access\n\nHere's a JSON policy that grants read-only access to all objects in the 'company-data' S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:GetObjectTagging\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data/*\"\n    },\n    {\n      \"Sid\": \"S3BucketListAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\",\n        \"s3:ListBucketVersions\"\n      ],\n      \"Resource\": \"arn:aws:s3:::company-data\"\n    }\n  ]\n}\n```\n\n## Policy Explanation:\n\n| Component | Details |\n|-----------|---------|\n| **First Statement (S3ReadOnlyAccess)** | Allows reading object content and metadata |\n| `s3:GetObject` | Read object data |\n| `s3:GetObjectVersion` | Read specific object versions |\n| `s3:GetObjectTagging` | Read object tags |\n| **Second Statement (S3BucketListAccess)** | Allows listing bucket contents |\n| `s3:ListBucket` | List objects in the bucket |\n| `s3:GetBucketVersioning` | Check versioning status |\n| `s3:ListBucketVersions` | List object versions |\n\nThis policy provides comprehensive read-only access while preventing any write, delete, or administrative operations on the bucket.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to all objects in an S3 bucket named 'company-data'"
#     },
#     "score": 8,
#     "reasoning": "The policy correctly implements read-only S3 access with proper ARN formatting and appropriate action grouping. It successfully prevents write/delete operations while enabling object retrieval. The inclusion of version-related actions is slightly over-permissive for a minimal read-only policy, and the solution lacks context about policy attachment. However, the core requirement is fully met with sound security practices."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[a-z0-9]{17}$\n```\n\n## Explanation\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string (anchor) |\n| `i-` | Literal prefix \"i-\" |\n| `[a-z0-9]` | Character class matching lowercase letters (a-z) or digits (0-9) |\n| `{17}` | Exactly 17 characters from the character class |\n| `$` | End of string (anchor) |\n\n## Examples\n\n### Valid matches:\n```\ni-1234567890abcdef0\ni-0a1b2c3d4e5f6g7h8\ni-abcdefghij1234567\n```\n\n### Invalid (won't match):\n```\ni-12345678901234567    (18 characters after i-)\ni-123456789012345      (16 characters after i-)\ni-1234567890ABCDEF0    (uppercase letters)\n1-1234567890abcdef0    (missing 'i' prefix)\nec2-1234567890abcdef0  (wrong prefix)\n```\n\n## Usage Examples\n\n**JavaScript:**\n```javascript\nconst regex = /^i-[a-z0-9]{17}$/;\nconsole.log(regex.test('i-1234567890abcdef0')); // true\nconsole.log(regex.test('i-123456789012345'));   // false\n```\n\n**Python:**\n```python\nimport re\nregex = r'^i-[a-z0-9]{17}$'\nprint(re.match(regex, 'i-1234567890abcdef0'))  # Match object\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 alphanumeric characters)"
#     },
#     "score": 6,
#     "reasoning": "The regex pattern itself is technically sound for the stated requirement of matching 'i-' followed by 17 alphanumeric characters. However, the solution contains a factual error in the examples (invalid character 'g' presented as valid) that undermines credibility. More critically, real AWS instance IDs use hexadecimal characters (0-9, a-f), so the pattern should be `^i-[a-f0-9]{17}$` for actual AWS compliance. The explanation is clear and well-formatted, but these accuracy issues are significant for a code review context."
#   }
# ]
