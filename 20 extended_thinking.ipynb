# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os

load_dotenv()

client = Anthropic(api_key=os.environ.get("ANTRHOPIC_API_KEY"))
model = "claude-haiku-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
redacted_thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "write one paragraph about recursion")
# add_user_message(messages, redacted_thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_011jgTe9bSbYw3TrSrifndxp', container=None, content=[ThinkingBlock(signature='...', thinking="The user is asking me to write a paragraph about recursion. This should explain what recursion is, how it works, and perhaps give some insight into its usefulness and applications. I'll aim for a clear, informative paragraph that covers the key concepts.\n\nKey points to cover:\n- Definition of recursion (a function calling itself)\n- Base case (to prevent infinite loops)\n- How it breaks down problems\n- Maybe an example or application\n- When it's useful\n\nLet me write a comprehensive paragraph.", type='thinking'), TextBlock(citations=None, text='# Recursion\n\nRecursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems until reaching a base case that stops the recursion. A recursive function must have a clear base case—a condition that returns a value without calling itself again—to prevent inf
# ...
