# %%
from dotenv import load_dotenv
import os
import anthropic

load_dotenv()

# Create client

client = anthropic.Anthropic(api_key=os.environ.get("ANTRHOPIC_API_KEY"))
model = "claude-sonnet-4-6"


# Make an initial list of message

messages = []

# Add user message
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# Add asst message
def add_asst_message(messages, text):
    asst_msg = {"role": "assistant", "content": text}
    messages.append(asst_msg)


# Chat
def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=500,
        messages=messages
    )
    return message.content[0].text


# User input until while true

while True:
    user_input = input("Press N to stop. Ask now > ")
    
    if user_input == "N":
        break
    
    print(">", user_input)
    add_user_message(messages, user_input)
    answer = chat(messages)
    print("----")
    print(answer)
    add_asst_message(messages, answer)
# Out:
# > what is 1+1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 47
#      44     break
#      46 print(">", user_input)
# ---> 47 add_user_message(messages, user_input)
#      48 answer = chat(messages)
#      49 print("----")
#
# Cell In[3], line 19, in add_user_message(messages, text)
#      18 def add_user_message(messages, text):
# ---> 19     user_message = {"role":"user", messages: text}
#      20     messages.append(user_message)
#
# TypeError: unhashable type: 'list'
