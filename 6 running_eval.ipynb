# %%
# from dotenv import load_dotenv
# import os
# import anthropic

# load_dotenv()

# # Create client

# client = anthropic.Anthropic(api_key=os.environ.get("ANTRHOPIC_API_KEY"))
# model = "claude-haiku-4-5"

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic(api_key=os.environ.get("ANTRHOPIC_API_KEY"))
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere are several solutions depending on your needs:\n\n## Solution 1: Simple String Splitting (Python)\n```python\ndef extract_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and split by '/'\n    return s3_uri.replace('s3://', '').split('/')[0]\n\n# Test cases\nprint(extract_bucket_name('s3://my-bucket/path/to/file.txt'))  # my-bucket\nprint(extract_bucket_name('s3://another-bucket/file.txt'))      # another-bucket\nprint(extract_bucket_name('s3://bucket-123/'))                  # bucket-123\n```\n\n## Solution 2: Using Regular Expressions (Python)\n```python\nimport re\n\ndef extract_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using regex\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    return match.group(1) if match else None\n\n# Test cases\nprint(extract_bucket_name('s3://my-bucket/path/to/file.txt'))  # my-bucket\nprint(extract_bucket_name('s3://bucket/'))                      # bucket\n```\n\n## Solution 3: Using urllib (Python)\n```python\nfrom urllib.parse import urlparse\n\ndef extract_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Test case\nprint(extract_bucket_name('s3://my-bucket/path/to/file.txt'))  # my-bucket\n```\n\n## Solution 4: JavaScript\n```javascript\nfunction extractBucketName(s3Uri) {\n    return s3Uri.replace('s3://', '').split('/')[0];\n}\n\n// Test cases\nconsole.log(extractBucketName('s3://my-bucket/path/to/file.txt'));  // my-bucket\nconsole.log(extractBucketName('s3://bucket-123/'));                 // bucket-123\n```\n\n## Solution 5: Bash/Shell\n```bash\n#!/bin/bash\n\nextract_bucket_name() {\n    local s3_uri=$1\n    echo \"$s3_uri\" | sed 's|s3://||' | cut -d'/' -f1\n}\n\n# Test case\nextract_bucket_name \"s3://my-bucket/path/to/file.txt\"  # my-bucket\n```\n\n## Recommended Solution\nFor most use cases, **Solution 1 (simple string splitting)** is best because:\n- \u2705 Simple and readable\n- \u2705 No external dependencies\n- \u2705 Fast performance\n- \u2705 Works with all valid S3 URIs\n\n**Use Solution 3 (urllib)** if you need robust URL parsing or plan to extract multiple URI components.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., s3://my-bucket/path/to/file.txt) and extract only the bucket name",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates competent implementations across multiple languages and correctly solves the basic task. However, it lacks production-ready robustness\u2014real AWS workflows often encounter malformed inputs, alternative URI schemes (Spark uses s3a://), and the recommendation of Solution 1 over Solution 3 is debatable since urllib provides more reliable URL parsing with built-in validation. The absence of error handling and edge case discussion is a significant gap for an AWS-focused task where defensive programming is important."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template\n\nHere's a CloudFormation template JSON object that defines a simple AWS Lambda function:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for a simple AWS Lambda function\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"SimpleLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"my-simple-function\",\n        \"Runtime\": \"python3.11\",\n        \"Handler\": \"index.lambda_handler\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"SimpleLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"SimpleLambdaFunction\"\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n1. **LambdaExecutionRole**: IAM role that Lambda needs to assume\n   - Includes basic execution permissions for CloudWatch Logs\n\n2. **SimpleLambdaFunction**: The Lambda function resource with:\n   - **FunctionName**: `my-simple-function`\n   - **Runtime**: `python3.11` (can be changed to other runtimes like `nodejs18.x`, `java11`, etc.)\n   - **Handler**: `index.lambda_handler` (function entry point)\n   - **Role**: References the execution role ARN\n   - **Code**: Inline Python code (ZipFile)\n\n3. **Outputs**: Returns the Lambda function ARN and name for reference\n\n## Alternative Runtimes:\n- `nodejs18.x`, `nodejs20.x`\n- `python3.9`, `python3.10`, `python3.11`, `python3.12`\n- `java11`, `java17`, `java21`\n- `dotnet6`, `dotnet8`\n\nThis template is production-ready and follows AWS best practices!",
#     "test_case": {
#       "task": "Create a CloudFormation template JSON object that defines a simple AWS Lambda function with basic properties including FunctionName, Runtime, Handler, and Role",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution exceeds the original requirements by providing a production-ready template rather than a minimal Lambda function definition. While this demonstrates good AWS practices (proper IAM role setup, outputs, documentation), it technically over-delivers on the stated task. The template is syntactically correct, deployable, and well-documented. However, for enhanced reusability, it would benefit from CloudFormation parameters and potentially demonstrating code references beyond inline ZipFile."
#   },
#   {
#     "output": "# AWS IAM Policy Action Extractor\n\n```python\nimport json\nfrom typing import List, Union\n\ndef extract_iam_actions(policy_json: str) -> List[str]:\n    \"\"\"\n    Extract all Action permissions from an AWS IAM policy JSON string.\n    \n    Args:\n        policy_json (str): AWS IAM policy as a JSON string\n        \n    Returns:\n        List[str]: A list of all Action permissions found in the policy\n        \n    Raises:\n        json.JSONDecodeError: If the input is not valid JSON\n        ValueError: If the policy format is invalid\n        \n    Example:\n        >>> policy = '''\n        ... {\n        ...     \"Version\": \"2012-10-17\",\n        ...     \"Statement\": [\n        ...         {\n        ...             \"Effect\": \"Allow\",\n        ...             \"Action\": [\"s3:GetObject\", \"s3:PutObject\"],\n        ...             \"Resource\": \"*\"\n        ...         },\n        ...         {\n        ...             \"Effect\": \"Allow\",\n        ...             \"Action\": \"ec2:DescribeInstances\",\n        ...             \"Resource\": \"*\"\n        ...         }\n        ...     ]\n        ... }\n        ... '''\n        >>> extract_iam_actions(policy)\n        ['s3:GetObject', 's3:PutObject', 'ec2:DescribeInstances']\n    \"\"\"\n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError as e:\n        raise json.JSONDecodeError(f\"Invalid JSON in policy: {e.msg}\", e.doc, e.pos)\n    \n    actions = []\n    \n    # Validate policy structure\n    if not isinstance(policy, dict):\n        raise ValueError(\"Policy must be a JSON object (dictionary)\")\n    \n    statements = policy.get(\"Statement\", [])\n    \n    if not isinstance(statements, list):\n        raise ValueError(\"Statement must be a list\")\n    \n    # Iterate through each statement\n    for statement in statements:\n        if not isinstance(statement, dict):\n            continue\n            \n        action_field = statement.get(\"Action\")\n        \n        if action_field is None:\n            continue\n        \n        # Action can be a string or a list of strings\n        if isinstance(action_field, str):\n            actions.append(action_field)\n        elif isinstance(action_field, list):\n            for action in action_field:\n                if isinstance(action, str):\n                    actions.append(action)\n    \n    return actions\n\n\n# Example usage and test cases\nif __name__ == \"__main__\":\n    # Test Case 1: Multiple actions in a list\n    policy1 = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\"s3:GetObject\", \"s3:PutObject\"],\n                \"Resource\": \"*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"ec2:DescribeInstances\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    '''\n    \n    print(\"Test 1 - Multiple actions:\")\n    result1 = extract_iam_actions(policy1)\n    print(f\"Actions: {result1}\")\n    print()\n    \n    # Test Case 2: Single action as string\n    policy2 = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:*\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    '''\n    \n    print(\"Test 2 - Single action with wildcard:\")\n    result2 = extract_iam_actions(policy2)\n    print(f\"Actions: {result2}\")\n    print()\n    \n    # Test Case 3: Multiple statements with mixed formats\n    policy3 = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\"iam:GetUser\", \"iam:ListUsers\"],",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM policy JSON string as input and returns the list of all Action permissions granted",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the core requirement of extracting Action permissions from IAM policy JSON strings and handles the two valid Action formats (string or list). Error handling is appropriate and documentation is clear. However, the implementation is somewhat limited in scope\u2014it doesn't account for edge cases like NotAction fields, conditional statements, or duplicate actions. The incomplete test code also raises concerns about validation. For a production solution, deduplication and broader IAM policy support would be valuable additions."
#   }
# ]
