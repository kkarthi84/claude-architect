# %%
from dotenv import load_dotenv
import os
import anthropic

load_dotenv()

# Create client

client = anthropic.Anthropic(api_key=os.environ.get("ANTRHOPIC_API_KEY"))
model = "claude-haiku-4-5"


# Make an initial list of message

messages = []

# Add user message
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# Add asst message
def add_asst_message(messages, text):
    asst_msg = {"role": "assistant", "content": text}
    messages.append(asst_msg)


# Chat
def chat(messages, system=None, temperature=0.5):
    params = {
        "model":model,
        "max_tokens":200,
        "messages":messages,
        "temperature":temperature
    }
    if system:
        params["system"] = system

    message = client.messages.create(**params)

    return message.content[0].text


# User input until while true

while True:
    user_input = input("Press N to stop. Ask now > ")
    
    if user_input == "N":
        break
    
    # system = """
    # You are a math tutor, Do not directly give answers to students question. Guide step by step. Make student to think.
    # """
    system = """
    You are python developer, write very concise code
    """
    print(">", user_input)
    add_user_message(messages, user_input)
    temperature = 0.0
    answer = chat(messages, system, temperature)
    print("----")
    print(answer)
    add_asst_message(messages, answer)
# Out:
# > one sentence idea for picking stocks using agents
# ----
# Use AI agents to analyze real-time market data, news sentiment, and financial metrics to autonomously identify and rank undervalued stocks matching your investment criteria.
